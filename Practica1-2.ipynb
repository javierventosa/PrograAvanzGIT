# %% [markdown]
# <a href="https://colab.research.google.com/github/javierventosa/PrograAvanzGIT/blob/main/Practica1-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ejercicio 1

for i in range(1, 6):
    if i % 2 == 0:
        continue  # Omitir números pares
    for j in range(1, 11):
        product = i * j
        if product > 20:
            break  # Detener si el producto supera 20
        print(f"{i} x {j} = {product}")
        pass  # Uso de pass sin afectar la lógica

#Ejercicio 2

  def process_text(text="Este es un texto de ejemplo.", words_to_replace=None):
    if words_to_replace is None:
        words_to_replace = ["texto", "ejemplo"]

    # Convertir la cadena a minúsculas
    text = text.lower()

    # Eliminar los espacios en blanco iniciales y finales
    text = text.strip()

    # Reemplazar las palabras especificadas con asteriscos
    replaced_count = 0
    for word in words_to_replace:
        if word in text:
            text = text.replace(word, '*' * len(word))
            replaced_count += 1

    return text, replaced_count

def main():
    processed_text, count = process_text()
    print(f"Texto procesado: {processed_text}")
    print(f"Cantidad de palabras reemplazadas: {count}")

if __name__ == "__main__":
    main()

#Ejercicio 3

  def is_prime(n):
    """
    Comprueba si un número n es primo.

    Args:
    n (int): El número a comprobar.

    Returns:
    bool: True si n es primo, False en caso contrario.
    """
    if n <= 1:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

def prime_list(limit):
    """
    Genera una lista de números primos hasta un límite.

    Args:
    limit (int): El límite hasta el cual generar números primos.

    Returns:
    list: Lista de números primos hasta el límite.
    """
    primes = []
    for num in range(2, limit + 1):
        if is_prime(num):
            primes.append(num)
    return primes

def check_palindrome(primes):
    """
    Busca palíndromos en una lista de números primos.

    Args:
    primes (list): Lista de números primos.

    Returns:
    list: Lista de números primos que son palíndromos.
    """
    palindromes = []
    for prime in primes:
        if str(prime) == str(prime)[::-1]:
            palindromes.append(prime)
    return palindromes

def categorize_prime(prime):
    """
    Clasifica los números primos en "pequeños", "medianos" o "grandes".

    Args:
    prime (int): El número primo a clasificar.

    Returns:
    str: La categoría del número primo ("pequeño", "mediano" o "grande").
    """
    if prime < 10:
        return "pequeño"
    elif 10 <= prime < 100:
        return "mediano"
    else:
        return "grande"

def main():
    limit = 100
    primes = prime_list(limit)
    print(f"Números primos hasta {limit}: {primes}")

    palindromic_primes = check_palindrome(primes)
    print(f"Números primos palíndromos: {palindromic_primes}")

    for prime in primes:
        category = categorize_prime(prime)
        print(f"El número primo {prime} es {category}")

if __name__ == "__main__":
    main()

#Ejercicio 4

def sum_all(numbers):
    """
    Calcula la suma de todos los números en la lista.

    Args:
    numbers (list): Lista de números enteros.

    Returns:
    int: Suma de todos los números.
    """
    return sum(numbers)

def sum_positive_negative(numbers):
    """
    Calcula la suma de los números positivos y negativos por separado.

    Args:
    numbers (list): Lista de números enteros.

    Returns:
    tuple: Suma de los números positivos y suma de los números negativos.
    """
    positive_sum = sum(n for n in numbers if n > 0)
    negative_sum = sum(n for n in numbers if n < 0)
    return positive_sum, negative_sum

def find_max_min(numbers):
    """
    Encuentra el número máximo y mínimo de la lista.

    Args:
    numbers (list): Lista de números enteros.

    Returns:
    tuple: Número máximo y número mínimo.
    """
    return max(numbers), min(numbers)

def are_all_unique(numbers):
    """
    Comprueba si todos los números de la lista son únicos.

    Args:
    numbers (list): Lista de números enteros.

    Returns:
    bool: True si todos los números son únicos, False en caso contrario.
    """
    return len(numbers) == len(set(numbers))

def compare_positive_negative(numbers):
    """
    Devuelve un mensaje que indica si la lista contiene más números positivos o negativos.

    Args:
    numbers (list): Lista de números enteros.

    Returns:
    str: Mensaje indicando si hay más números positivos o negativos.
    """
    positive_count = sum(1 for n in numbers if n > 0)
    negative_count = sum(1 for n in numbers if n < 0)
    return "Más números positivos" if positive_count > negative_count else "Más números negativos"

def main():
    numbers = list(map(int, input("Ingrese una lista de números enteros separados por espacios: ").split()))

    while True:
        print("\nMenú de opciones:")
        print("1. Calcular la suma de todos los números")
        print("2. Calcular la suma de los números positivos y negativos por separado")
        print("3. Encontrar el número máximo y mínimo de la lista")
        print("4. Comprobar si todos los números de la lista son únicos")
        print("5. Comparar la cantidad de números positivos y negativos")
        print("6. Salir")

        option = int(input("Seleccione una opción: "))

        if option == 1:
            print(f"Suma de todos los números: {sum_all(numbers)}")
        elif option == 2:
            positive_sum, negative_sum = sum_positive_negative(numbers)
            print(f"Suma de los números positivos: {positive_sum}")
            print(f"Suma de los números negativos: {negative_sum}")
        elif option == 3:
            max_num, min_num = find_max_min(numbers)
            print(f"Número máximo: {max_num}")
            print(f"Número mínimo: {min_num}")
        elif option == 4:
            print(f"Todos los números son únicos: {are_all_unique(numbers)}")
        elif option == 5:
            print(compare_positive_negative(numbers))
        elif option == 6:
            print("Saliendo del programa...")
            break
        else:
            print("Opción no válida. Intente de nuevo.")

if __name__ == "__main__":
    main()

#Ejercicio 5

# Lista global de tareas
tasks = []

def add_task(task):
    """
    Agrega una nueva tarea a la lista global de tareas.

    Args:
    task (str): La tarea a agregar.
    """
    global tasks
    tasks.append(task)
    print(f"Tarea '{task}' agregada.")

def remove_task(task):
    """
    Elimina una tarea de la lista global de tareas, si existe.

    Args:
    task (str): La tarea a eliminar.
    """
    global tasks
    if task in tasks:
        tasks.remove(task)
        print(f"Tarea '{task}' eliminada.")
    else:
        print(f"Tarea '{task}' no encontrada.")

def list_tasks():
    """
    Enumera todas las tareas almacenadas en la lista global de tareas.
    """
    global tasks
    if tasks:
        print("Lista de tareas:")
        for idx, task in enumerate(tasks, 1):
            print(f"{idx}. {task}")
    else:
        print("No hay tareas en la lista.")

def task_manager():
    """
    Administra las operaciones de agregar, modificar y enumerar tareas.
    """
    def modify_task():
        """
        Modifica la primera tarea en la lista de tareas.
        """
        global tasks
        if tasks:
            new_task = input("Ingrese la nueva descripción para la primera tarea: ")
            tasks[0] = new_task
            print("Primera tarea modificada.")
        else:
            print("No hay tareas para modificar.")

    while True:
        print("\nMenú de administración de tareas:")
        print("1. Agregar tarea")
        print("2. Eliminar tarea")
        print("3. Listar tareas")
        print("4. Modificar primera tarea")
        print("5. Salir")

        option = int(input("Seleccione una opción: "))

        if option == 1:
            task = input("Ingrese la tarea a agregar: ")
            add_task(task)
        elif option == 2:
            task = input("Ingrese la tarea a eliminar: ")
            remove_task(task)
        elif option == 3:
            list_tasks()
        elif option == 4:
            modify_task()
        elif option == 5:
            print("Saliendo del administrador de tareas...")
            break
        else:
            print("Opción no válida. Intente de nuevo.")

def main():
    task_manager()

if __name__ == "__main__":
    main()

#Ejercicio 6

# Lista global de cadenas
strings = []

def print_strings_starting_with(letter):
    """
    Imprime cada cadena que comience con una letra pedida al usuario.

    Args:
    letter (str): La letra con la que deben comenzar las cadenas.
    """
    global strings
    for string in strings:
        if string.startswith(letter):
            print(string)

def count_strings_containing(substring):
    """
    Cuenta cuántas cadenas contienen una subcadena pedida al usuario.

    Args:
    substring (str): La subcadena a buscar en las cadenas.

    Returns:
    int: La cantidad de cadenas que contienen la subcadena.
    """
    global strings
    count = sum(1 for string in strings if substring in string)
    return count

def find_longest_and_shortest():
    """
    Encuentra la cadena más larga y la más corta de la lista.

    Returns:
    tuple: La cadena más larga y la más corta.
    """
    global strings
    if not strings:
        return None, None
    longest = max(strings, key=len)
    shortest = min(strings, key=len)
    return longest, shortest

def check_same_object(str1, str2):
    """
    Verifica si dos cadenas específicas de la lista son en realidad el mismo objeto.

    Args:
    str1 (str): La primera cadena.
    str2 (str): La segunda cadena.

    Returns:
    bool: True si son el mismo objeto, False en caso contrario.
    """
    return str1 is str2

def check_length_greater_than_10():
    """
    Verifica si alguna cadena de la lista tiene una longitud mayor que 10.
    Si no es así, imprime un mensaje que indique que ninguna cadena tiene más de 10 caracteres.
    """
    global strings
    for string in strings:
        if len(string) > 10:
            print(f"La cadena '{string}' tiene más de 10 caracteres.")
            break
    else:
        print("Ninguna cadena tiene más de 10 caracteres.")

def main():
    global strings
    strings = input("Ingrese una lista de cadenas separadas por comas: ").split(',')
    strings = [s.strip() for s in strings]

    while True:
        print("\nMenú de opciones:")
        print("1. Imprimir cadenas que comiencen con una letra específica")
        print("2. Contar cadenas que contienen una subcadena específica")
        print("3. Encontrar la cadena más larga y la más corta")
        print("4. Verificar si dos cadenas son el mismo objeto")
        print("5. Verificar si alguna cadena tiene más de 10 caracteres")
        print("6. Salir")

        option = int(input("Seleccione una opción: "))

        if option == 1:
            letter = input("Ingrese la letra: ")
            print_strings_starting_with(letter)
        elif option == 2:
            substring = input("Ingrese la subcadena: ")
            count = count_strings_containing(substring)
            print(f"Cantidad de cadenas que contienen '{substring}': {count}")
        elif option == 3:
            longest, shortest = find_longest_and_shortest()
            print(f"Cadena más larga: {longest}")
            print(f"Cadena más corta: {shortest}")
        elif option == 4:
            str1 = input("Ingrese la primera cadena: ")
            str2 = input("Ingrese la segunda cadena: ")
            same_object = check_same_object(str1, str2)
            print(f"Las cadenas son el mismo objeto: {same_object}")
        elif option == 5:
            check_length_greater_than_10()
        elif option == 6:
            print("Saliendo del programa...")
            break
        else:
            print("Opción no válida. Intente de nuevo.")

if __name__ == "__main__":
    main()
